# %%
# !pip install llama-index --quiet
# !pip install langchain --quiet
# !pip install llama-hub --quiet
# !pip install singlestoredb --quiet

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-xxx"

# %%
from langchain.vectorstores import SingleStoreDB

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://gpt-index.readthedocs.io/en/latest/")
data = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 0)
all_splits = text_splitter.split_documents(data)

# %%
from langchain.embeddings import OpenAIEmbeddings
os.environ["SINGLESTOREDB_URL"] = "admin:password@svc-56441794-b2ba-46ad-bc0b-c3d5810a45f4-dml.aws-oregon-3.svc.singlestore.com:3306/demo"

# vectorstore = SingleStoreDB.from_documents(documents=all_splits, embedding=OpenAIEmbeddings())
vectorstore = SingleStoreDB(embedding=OpenAIEmbeddings())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\GitHub\Data_Science_learnig\Building a Gen AI App with lamaindex and singlestore\01_test.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> os.environ["SINGLESTOREDB_URL"] = "admin:password@svc-56441794-b2ba-46ad-bc0b-c3d5810a45f4-dml.aws-oregon-3.svc.singlestore.com:3306/demo"
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> # vectorstore = SingleStoreDB.from_documents(documents=all_splits, embedding=OpenAIEmbeddings())
# ----> <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> vectorstore = SingleStoreDB(embedding=OpenAIEmbeddings())
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\langchain\vectorstores\singlestoredb.py:211, in SingleStoreDB.__init__(self, embedding, distance_strategy, table_name, content_field, metadata_field, vector_field, pool_size, max_overflow, timeout, **kwargs)
#     204 """Create connection pool."""
#     205 self.connection_pool = QueuePool(
#     206     self._get_connection,
#     207     max_overflow=max_overflow,
#     208     pool_size=pool_size,
#     209     timeout=timeout,
#     210 )
# --> 211 self._create_table()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\langchain\vectorstores\singlestoredb.py:222, in SingleStoreDB._create_table(self)
#     220 def _create_table(self: SingleStoreDB) -> None:
#     221     """Create table if it doesn't exist."""
# --> 222     conn = self.connection_pool.connect()
#     223     try:
#     224         cur = conn.cursor()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:1267, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1259 @classmethod
#    1260 def _checkout(
#    1261     cls,
#    (...)
#    1264     fairy: Optional[_ConnectionFairy] = None,
#    1265 ) -> _ConnectionFairy:
#    1266     if not fairy:
# -> 1267         fairy = _ConnectionRecord.checkout(pool)
#    1269         if threadconns is not None:
#    1270             threadconns.current = weakref.ref(fairy)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\impl.py:169, in QueuePool._do_get(self)
#     167     return self._create_connection()
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#     171     raise
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:902, in _ConnectionRecord.__connect(self)
#     900     self.fresh = True
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:365, in Pool._should_wrap_creator.<locals>.<lambda>(rec)
#     361 # all other cases, just wrap and assume legacy "creator" callable
#     362 # thing
#     363 else:
#     364     creator_fn = cast(_CreatorFnType, creator)
# --> 365     return lambda rec: creator_fn()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\langchain\vectorstores\singlestoredb.py:54, in SingleStoreDB._get_connection(self)
#      49 except ImportError:
#      50     raise ImportError(
#      51         "Could not import singlestoredb python package. "
#      52         "Please install it with `pip install singlestoredb`."
#      53     )
# ---> 54 return s2.connect(**self.connection_kwargs)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\singlestoredb\connection.py:1418, in connect(host, user, password, port, database, driver, pure_python, local_infile, charset, ssl_key, ssl_cert, ssl_ca, ssl_disabled, ssl_cipher, ssl_verify_cert, ssl_verify_identity, conv, credential_type, autocommit, results_type, buffered, results_format, program_name, conn_attrs, multi_statements, connect_timeout, nan_as_null, inf_as_null, encoding_errors)
#    1416 if not driver or driver == 'mysql':
#    1417     from .mysql.connection import Connection  # type: ignore
# -> 1418     return Connection(**params)
#    1420 if driver in ['http', 'https']:
#    1421     from .http.connection import Connection
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\singlestoredb\mysql\connection.py:538, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_cipher, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, parse_json, invalid_values, pure_python, buffered, results_type, compress, named_pipe, passwd, db, driver, conn_attrs, multi_statements, nan_as_null, inf_as_null, encoding_errors)
#     536     self._sock = None
#     537 else:
# --> 538     self.connect()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\singlestoredb\mysql\connection.py:906, in Connection.connect(self, sock)
#     903 self._next_seq_id = 0
#     905 self._get_server_information()
# --> 906 self._request_authentication()
#     908 # Send "SET NAMES" query on init for:
#     909 # - Ensure charaset (and collation) is set to the server.
#     910 #   - collation_id in handshake packet may be ignored.
#    (...)
#     919 # - https://github.com/wagtail/wagtail/issues/9477
#     920 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     921 self.set_character_set(self.charset, self.collation)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\singlestoredb\mysql\connection.py:1207, in Connection._request_authentication(self)
#    1204     data += _lenenc_int(len(connect_attrs)) + connect_attrs
#    1206 self.write_packet(data)
# -> 1207 auth_packet = self._read_packet()
#    1209 # if authentication method isn't accepted the first byte
#    1210 # will have the octet 254
#    1211 if auth_packet.is_auth_switch_request():
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\singlestoredb\mysql\connection.py:1024, in Connection._read_packet(self, packet_type)
#    1022     if self._result is not None and self._result.unbuffered_active is True:
#    1023         self._result.unbuffered_active = False
# -> 1024     packet.raise_for_error()
#    1025 return packet
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\singlestoredb\mysql\protocol.py:234, in MysqlPacket.raise_for_error(self)
#     232 if DEBUG:
#     233     print('errno =', errno)
# --> 234 err.raise_mysql_exception(self._data)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\singlestoredb\mysql\err.py:92, in raise_mysql_exception(data)
#      90 if errorclass is None:
#      91     errorclass = InternalError if errno < 1000 else OperationalError
# ---> 92 raise errorclass(errno, errval)
#
# OperationalError: 1045: Access denied for user 'admin'@'103.18.75.226' (using password: YES)

# %%
from llama_index import download_loader

SingleStoreReader = download_loader("SingleStoreReader")

reader = SingleStoreReader(
    scheme="mysql",
    host="svc-56441794-b2ba-46ad-bc0b-c3d5810a45f4-dml.aws-oregon-3.svc.singlestore.com",
    port="3306",
    user="admin",
    password="password",
    dbname="demo",
    table_name="embeddings",
    content_field="content",
    vector_field="vector"
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\base.py:3288, in Engine.raw_connection(self)
#    3267 """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269 The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287 """
# -> 3288 return self.pool.connect()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:1267, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1266 if not fairy:
# -> 1267     fairy = _ConnectionRecord.checkout(pool)
#    1269     if threadconns is not None:
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\impl.py:169, in QueuePool._do_get(self)
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\impl.py:167, in QueuePool._do_get(self)
#     166 try:
# --> 167     return self._create_connection()
#     168 except:
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:902, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\default.py:615, in DefaultDialect.connect(self, *cargs, **cparams)
#     613 def connect(self, *cargs, **cparams):
#     614     # inherits the docstring from interfaces.Dialect.connect
# --> 615     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     357 else:
# --> 358     self.connect()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\connections.py:664, in Connection.connect(self, sock)
#     663 self._get_server_information()
# --> 664 self._request_authentication()
#     666 # Send "SET NAMES" query on init for:
#     667 # - Ensure charaset (and collation) is set to the server.
#     668 #   - collation_id in handshake packet may be ignored.
#    (...)
#     677 # - https://github.com/wagtail/wagtail/issues/9477
#     678 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\connections.py:954, in Connection._request_authentication(self)
#     953 self.write_packet(data)
# --> 954 auth_packet = self._read_packet()
#     956 # if authentication method isn't accepted the first byte
#     957 # will have the octet 254
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'admin'@'103.18.75.226' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# c:\GitHub\Data_Science_learnig\Building a Gen AI App with lamaindex and singlestore\01_test.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from llama_index import download_loader
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> SingleStoreReader = download_loader("SingleStoreReader")
# ----> <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> reader = SingleStoreReader(
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     scheme="mysql",
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>     host="svc-56441794-b2ba-46ad-bc0b-c3d5810a45f4-dml.aws-oregon-3.svc.singlestore.com",
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     port="3306",
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>     user="admin",
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>     password="password",
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a>     dbname="demo",
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>     table_name="embeddings",
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a>     content_field="content",
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a>     vector_field="vector"
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Data_Science_learnig/Building%20a%20Gen%20AI%20App%20with%20lamaindex%20and%20singlestore/01_test.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a> )
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\llama_index\readers\llamahub_modules/singlestore/base.py:49, in SingleStoreReader.__init__(self, scheme, host, port, user, password, dbname, table_name, content_field, vector_field)
#      46 except:
#      47     self.DatabaseReader = download_loader('DatabaseReader')
# ---> 49 self.reader = self.DatabaseReader(
#      50     scheme=self.scheme,
#      51     host=self.host,
#      52     port=self.port,
#      53     user=self.user,
#      54     password=self.password,
#      55     dbname=self.dbname,
#      56 )
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\llama_hub\database\base.py:69, in DatabaseReader.__init__(self, sql_database, engine, uri, scheme, host, port, user, password, dbname, *args, **kwargs)
#      67     uri = f"{scheme}://{user}:{password}@{host}:{port}/{dbname}"
#      68     self.uri = uri
# ---> 69     self.sql_database = SQLDatabase.from_uri(uri, *args, **kwargs)
#      70 else:
#      71     raise ValueError(
#      72         "You must provide either a SQLDatabase, "
#      73         "a SQL Alchemy Engine, a valid connection URI, or a valid "
#      74         "set of credentials."
#      75     )
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\llama_index\langchain_helpers\sql_wrapper.py:38, in SQLDatabase.from_uri(cls, database_uri, engine_args, **kwargs)
#      36 """Construct a SQLAlchemy engine from URI."""
#      37 _engine_args = engine_args or {}
# ---> 38 return cls(create_engine(database_uri, **_engine_args), **kwargs)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\langchain\utilities\sql_database.py:61, in SQLDatabase.__init__(self, engine, schema, metadata, ignore_tables, include_tables, sample_rows_in_table_info, indexes_in_table_info, custom_table_info, view_support, max_string_length)
#      58 if include_tables and ignore_tables:
#      59     raise ValueError("Cannot specify both include_tables and ignore_tables")
# ---> 61 self._inspector = inspect(self._engine)
#      63 # including view support by adding the views as well as tables to the all
#      64 # tables list if view_support is True
#      65 self._all_tables = set(
#      66     self._inspector.get_table_names(schema=schema)
#      67     + (self._inspector.get_view_names(schema=schema) if view_support else [])
#      68 )
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\inspection.py:145, in inspect(subject, raiseerr)
#     143 elif reg is True:
#     144     return subject
# --> 145 ret = reg(subject)
#     146 if ret is not None:
#     147     return ret
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\reflection.py:303, in Inspector._engine_insp(bind)
#     301 @inspection._inspects(Engine)
#     302 def _engine_insp(bind: Engine) -> Inspector:  # type: ignore[misc]
# --> 303     return Inspector._construct(Inspector._init_engine, bind)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\reflection.py:236, in Inspector._construct(cls, init, bind)
#     233     cls = bind.dialect.inspector
#     235 self = cls.__new__(cls)
# --> 236 init(self, bind)
#     237 return self
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\reflection.py:247, in Inspector._init_engine(self, engine)
#     245 def _init_engine(self, engine: Engine) -> None:
#     246     self.bind = self.engine = engine
# --> 247     engine.connect().close()
#     248     self._op_context_requires_connect = True
#     249     self.dialect = self.engine.dialect
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\base.py:3264, in Engine.connect(self)
#    3241 def connect(self) -> Connection:
#    3242     """Return a new :class:`_engine.Connection` object.
#    3243
#    3244     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3261
#    3262     """
# -> 3264     return self._connection_cls(self)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\base.py:2426, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2424 elif should_wrap:
#    2425     assert sqlalchemy_exception is not None
# -> 2426     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2427 else:
#    2428     assert exc_info[1] is not None
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\base.py:3288, in Engine.raw_connection(self)
#    3266 def raw_connection(self) -> PoolProxiedConnection:
#    3267     """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269     The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287     """
# -> 3288     return self.pool.connect()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:1267, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1259 @classmethod
#    1260 def _checkout(
#    1261     cls,
#    (...)
#    1264     fairy: Optional[_ConnectionFairy] = None,
#    1265 ) -> _ConnectionFairy:
#    1266     if not fairy:
# -> 1267         fairy = _ConnectionRecord.checkout(pool)
#    1269         if threadconns is not None:
#    1270             threadconns.current = weakref.ref(fairy)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\impl.py:169, in QueuePool._do_get(self)
#     167     return self._create_connection()
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#     171     raise
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:902, in _ConnectionRecord.__connect(self)
#     900     self.fresh = True
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\sqlalchemy\engine\default.py:615, in DefaultDialect.connect(self, *cargs, **cparams)
#     613 def connect(self, *cargs, **cparams):
#     614     # inherits the docstring from interfaces.Dialect.connect
# --> 615     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356     self._sock = None
#     357 else:
# --> 358     self.connect()
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\connections.py:664, in Connection.connect(self, sock)
#     661 self._next_seq_id = 0
#     663 self._get_server_information()
# --> 664 self._request_authentication()
#     666 # Send "SET NAMES" query on init for:
#     667 # - Ensure charaset (and collation) is set to the server.
#     668 #   - collation_id in handshake packet may be ignored.
#    (...)
#     677 # - https://github.com/wagtail/wagtail/issues/9477
#     678 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     679 self.set_character_set(self.charset, self.collation)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\connections.py:954, in Connection._request_authentication(self)
#     951     data += _lenenc_int(len(connect_attrs)) + connect_attrs
#     953 self.write_packet(data)
# --> 954 auth_packet = self._read_packet()
#     956 # if authentication method isn't accepted the first byte
#     957 # will have the octet 254
#     958 if auth_packet.is_auth_switch_request():
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\ProgramData\anaconda3\envs\SuperEnv\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'admin'@'103.18.75.226' (using password: YES)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
